# %%
import matplotlib.pyplot as plt

# %%
# %%bash
#
# cd simulation
# ./DLPOLY.Z
# Out:
#   Cell In[26], line 5
#     cd simulation
#        ^
# SyntaxError: invalid syntax

# %%
from ase.io import read,write
import py3Dmol

styles = ['line', 'stick', 'sphere']

def atomsView(a, size=(300, 300), style="stick",background='0xfeeeee'):

    assert style in styles

    write("temp.cif",a)
    c = open("temp.cif",'r').read()
    view = py3Dmol.view()
    view.addModel(c,'cif')
    view.setStyle({style:{}})
    view.setBackgroundColor(background)
    view.zoomTo()
    view.addUnitCell()

    return view

a=read("simulation/REVCON",format="dlp4")
a.wrap()

atomsView(a)
# Out:
# <div id="3dmolviewer_17176879604762604"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_17176879604762604" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.1.0/3Dmol-min.js');
# }
#
# var viewer_17176879604762604 = null;
# var warn = document.getElementById("3dmolwarning_17176879604762604");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17176879604762604 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17176879604762604"),{backgroundColor:"white"});
# viewer_17176879604762604.zoomTo();
# 	viewer_17176879604762604.addModel("data_image0\n_chemical_formula_structural       Li1512La648Zr432O5184\n_chemical_formula_sum              \"Li1512 La648 Zr432 O5184\"\n_cell_length_a       39.263474031\n_cell_length_b       39.263474031\n_cell_length_c       37.6783368236\n_cell_angle_alpha    90.0\n_cell_angle_beta     90.0\n_cell_angle_gamma    90.0\n\n_space_group_name_H-M_alt    \"P 1\"\n_space_group_IT_number       1\n\nloop_\n  _space_group_symop_operation_xyz\n  'x, y, z'\n\nloop_\n  _atom_site_type_symbol\n  _atom_site_label\n  _atom_site_symmetry_multiplicity\n  _atom_site_fract_x\n  _atom_site_fract_y\n  _atom_site_fract_z\n  _atom_site_occupancy\n  Li  Li1       1.0  0.1346441419275847  0.9723275274332028  0.2351253485119609  1.0000\n  Li  Li2       1.0  0.1280028312836483  0.9729498389734581  0.08996370330435755  1.0000\n  Li  Li3       1.0  0.19846966778455313  0.1414953480584434  0.17553703288350364  1.0000\n  Li  Li4       1.0  0.009927481574662703  0.9908844596146175  0.11075838016783432  1.0000\n  Li  Li5       1.0  0.20794672589475022  0.050128077445363836  0.991269498164421  1.0000\n  Li  Li6       1.0  0.12269545094752544  0.05821318165059443  0.1711753425634292  1.0000\n  Li  Li7       1.0  0.06434222318191689  0.06532663828918639  0.06606038267169412  1.0000\n  Li  Li8       1.0  0.2821805477847529  0.028707476906146105  0.24570992664414118  1.0000\n  Li  Li9       1.0  0.11712718445059286  0.09925639379039795  0.24856419971100965  1.0000\n  Li  Li10      1.0  0.24701150304078143  0.11613596001209127  0.08536619708185626  1.0000\n  Li  Li11      1.0  0.2747287354522783  0.1276507211777243  0.1655192951376172  1.0000\n  Li  Li12      1.0  0.2292353475623095  0.28156784983599253  0.1660948563971688  1.0000\n  Li  Li13      1.0  0.11610502545955927  0.046365969541122494  0.08919460619331283  1.0000\n  Li  Li14      1.0  0.23597438076123353  0.032397793633738785  0.2491968063759904  1.0000\n  Li  Li15      1.0  0.07767172985233492  0.2777322452768774  0.2108102590936253  1.0000\n  Li  Li16      1.0  0.1145746813042622  0.10325635158516673  0.1775999193469878  1.0000\n  Li  Li17      1.0  0.23067033494920033  0.13368818263141122  0.14767245268944382  1.0000\n  Li  Li18      1.0  0.2650960325564167  0.2921526781084951  0.14678996928377572  1.0000\n  Li  Li19      1.0  0.12327123881545966  0.06874943452198772  0.2207728758555436  1.0000\n  Li  Li20      1.0  0.22718610767751293  0.07164459310908193  0.056453538566694286  1.0000\n  Li  Li21      1.0  0.2612400141134113  0.13524111261289629  0.11666955087695373  1.0000\n  Li  Li22      1.0  0.06848499577182002  0.11282389152580995  0.2695418953216324  1.0000\n  Li  Li23      1.0  0.22341611251908328  0.24438496306832316  0.19061564831336905  1.0000\n  Li  Li24      1.0  0.2853307957710198  0.08916008507642592  0.18111527162010188  1.0000\n  Li  Li25      1.0  0.07337753036639846  0.05270293523609777  0.11140541175296338  1.0000\n  Li  Li26      1.0  0.11241829010125372  0.20240433403130517  0.16407806124626387  1.0000\n  Li  Li27      1.0  0.28176200764265985  0.1217934496378085  0.2086673751765882  1.0000\n  Li  Li28      1.0  0.055670309822157364  0.10414389304348208  0.05322919889987794  1.0000\n  Li  Li29      1.0  0.9659688159803426  0.17944106330064746  0.09385346191249765  1.0000\n  Li  Li30      1.0  0.027781296533739723  0.1927391556851308  0.24750495534502687  1.0000\n  Li  Li31      1.0  0.9576884560778208  0.9453921833481379  0.9998138514985458  1.0000\n  Li  Li32      1.0  0.12054140385701011  0.21466473319058302  0.00596160608817813  1.0000\n  Li  Li33      1.0  0.0613051180111964  0.19433467726201775  0.15167161318066857  1.0000\n  Li  Li34      1.0  0.2967626690598075  0.22699772205493254  0.004989903983294673  1.0000\n  Li  Li35      1.0  0.20995578212186142  0.20332957335096694  0.26719106358469336  1.0000\n  Li  Li36      1.0  0.1083422030266958  0.21600724493466306  0.07426109653140099  1.0000\n  Li  Li37      1.0  0.2815615039889642  0.300 ...

# %%
# !cat simulation/OUTPUT
# Out:
# #*****************************************************************
# #************  stfc/ccp5  program  library  package  ** D ********
# #************  daresbury laboratory general purpose  *** L *******
# #*         **  classical molecular dynamics program  **** \ ******
# #* DL_POLY **  authors:   i.t.todorov   &   w.smith  ***** P *****
# #*         **  version:  5.1.0    /  March 2021      ****** O ****
# #************  execution on           1 process(es)  ******* L ***
# #************  contributors' list:                   ******** Y **
# #************  ------------------------------------  *************
# #************  i.j.bush, h.a.boateng, r.davidchak,   *************
# #************  m.a.seaton, a.v.brukhno, a.m.elena,   *************
# #************  s.l.daraszewicz,g.khara,s.t.murphy    *************
# #************  j.madge,a.b.g.chalk,i.scivetti,       *************
# #************  j.wilkins                             *************
# #*****************************************************************
#
# I/O read method: parallel by using MPI-I/O (assumed)
# I/O write method: parallel by using MPI-I/O (assumed)
#
#  DL_POLY_4 terminated due to error    52
#
#  # error - end of FIELD or MPOLES file encountered
